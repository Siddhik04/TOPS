# %% [markdown]
# """Report on the Evolution of DataScience - Trace how data science has evolved over
# the years."""
# #Data science has grown from simple statistics in the past to a powerful field used everywhere today. In the early days, people used basic math to study data. With the invention of computers in the 1950s, data could be stored and processed faster. In the 1980s and 1990s, data science became more popular with the rise of databases and machine learning. In the 2000s, the internet and smartphones created “big data,” leading to new tools and technologies. Today, data science combines statistics, programming, and artificial intelligence to find patterns, make predictions, and help solve real-world problems in many areas.

# %%
#1
n = int(input("enter a positive integer:"))
if n > 0:
    total = n*(n+1)
    print("sum of n",n,"positive integers are:",total)
else:
    print("enter the positive integer:")
